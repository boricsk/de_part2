# %%
import pandas as pd
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import requests
#
# ModuleNotFoundError: No module named 'pandas'

# %%
url = r"https://archive-api.open-meteo.com/v1/era5?latitude=52.52&longitude=13.41&start_date=2021-01-01&end_date=2021-12-31&hourly=temperature_2m"
response = requests.get(url)
response.json()

# %%
url = r"https://archive-api.open-meteo.com/v1/era5"
startDate = '2023-06-01'
params = {
    "latitude" : 41.85,
    "longitude" : -87.65,
    "start_date" : startDate,
    "end_date" : startDate,
    "hourly" : "temperature_2m,wind_speed_10m,precipitation,rain"
}


response = requests.get(url, params=params)
response.json()
# Out:
# {'latitude': 41.862915,
#  'longitude': -87.64877,
#  'generationtime_ms': 4.138946533203125,
#  'utc_offset_seconds': 0,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 179.0,
#  'hourly_units': {'time': 'iso8601',
#   'temperature_2m': '°C',
#   'wind_speed_10m': 'km/h',
#   'precipitation': 'mm',
#   'rain': 'mm'},
#  'hourly': {'time': ['2023-06-01T00:00',
#    '2023-06-01T01:00',
#    '2023-06-01T02:00',
#    '2023-06-01T03:00',
#    '2023-06-01T04:00',
#    '2023-06-01T05:00',
#    '2023-06-01T06:00',
#    '2023-06-01T07:00',
#    '2023-06-01T08:00',
#    '2023-06-01T09:00',
#    '2023-06-01T10:00',
#    '2023-06-01T11:00',
#    '2023-06-01T12:00',
#    '2023-06-01T13:00',
#    '2023-06-01T14:00',
#    '2023-06-01T15:00',
#    '2023-06-01T16:00',
#    '2023-06-01T17:00',
#    '2023-06-01T18:00',
#    '2023-06-01T19:00',
#    '2023-06-01T20:00',
#    '2023-06-01T21:00',
#    '2023-06-01T22:00',
#    '2023-06-01T23:00'],
#   'temperature_2m': [23.6,
# ...
